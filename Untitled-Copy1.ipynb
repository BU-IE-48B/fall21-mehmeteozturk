# %%
library(readr)

x_acc <- read_table("D:/İndirilenler/uWaveGestureLibrary_X_TRAIN",col_names = FALSE)
y_acc <- read_table("D:/İndirilenler/uWaveGestureLibrary_Y_TRAIN",col_names = FALSE)
z_acc <- read_table("D:/İndirilenler/uWaveGestureLibrary_Z_TRAIN",col_names = FALSE)

x_move=as.vector(x_acc[92,])
z_move=as.vector(z_acc[92,])
y_move=as.vector(y_acc[92,])


total <- rbind(x_move,y_move,z_move)
total=t(total)
total=total[-1,]
total=as.data.frame(total)
names(total)=c('x_acc','y_acc','z_acc')




acceleration=as.ts(total)
acceleration
plot(acceleration)


velocity_x=cumsum(total$x_acc)
velocity_y=cumsum(total$y_acc)
velocity_z=cumsum(total$z_acc)

velocity=data.frame(velocity_x,velocity_y,velocity_z)
tsvelocity=as.ts(velocity)
plot(tsvelocity)

location_x=cumsum(velocity_x)
location_y=cumsum(velocity_y)
location_z=cumsum(velocity_z)
location=data.frame(location_x,location_y,location_z)
tslocation=as.ts(location)
location
plot(tslocation)
plot(location)

scatterplot3d(location,type = "h",main="Instance from Class 8")

# %%
install.packages("rlang")
# Out:
#   There is a binary version available but the source version is later:
#       binary source needs_compilation
# rlang 0.4.11 0.4.12              TRUE
#
#   Binaries will be installed
# Warning message:
# "package 'rlang' is in use and will not be installed"

# %%
x_move=as.vector(x_acc[128,])
z_move=as.vector(z_acc[128,])
y_move=as.vector(y_acc[128,])


total <- rbind(x_move,y_move,z_move)
total=t(total)
total=total[-1,]
total=as.data.frame(total)
names(total)=c('x_acc','y_acc','z_acc')

velocity_x=cumsum(total$x_acc)
velocity_y=cumsum(total$y_acc)
velocity_z=cumsum(total$z_acc)
velocity=data.frame(velocity_x,velocity_y,velocity_z)


location_x=cumsum(velocity_x)
location_y=cumsum(velocity_y)
location_z=cumsum(velocity_z)
location=data.frame(location_x,location_y,location_z)



scatterplot3d(location,type = "h",main="Instance from Class 6")
# Out:
# Plot with title "Instance from Class 6"

# %%
x_move=as.vector(x_acc[94,])
z_move=as.vector(z_acc[94,])
y_move=as.vector(y_acc[94,])


total <- rbind(x_move,y_move,z_move)
total=t(total)
total=total[-1,]
total=as.data.frame(total)
names(total)=c('x_acc','y_acc','z_acc')

velocity_x=cumsum(total$x_acc)
velocity_y=cumsum(total$y_acc)
velocity_z=cumsum(total$z_acc)
velocity=data.frame(velocity_x,velocity_y,velocity_z)


location_x=cumsum(velocity_x)
location_y=cumsum(velocity_y)
location_z=cumsum(velocity_z)
location=data.frame(location_x,location_y,location_z)



scatterplot3d(location,type = "h",main="Instance from Class 3")
# Out:
# Plot with title "Instance from Class 3"

# %%
x_move=as.vector(x_acc[120,])
z_move=as.vector(z_acc[120,])
y_move=as.vector(y_acc[120,])


total <- rbind(x_move,y_move,z_move)
total=t(total)
total=total[-1,]
total=as.data.frame(total)
names(total)=c('x_acc','y_acc','z_acc')

velocity_x=cumsum(total$x_acc)
velocity_y=cumsum(total$y_acc)
velocity_z=cumsum(total$z_acc)
velocity=data.frame(velocity_x,velocity_y,velocity_z)


location_x=cumsum(velocity_x)
location_y=cumsum(velocity_y)
location_z=cumsum(velocity_z)
location=data.frame(location_x,location_y,location_z)



scatterplot3d(location,type = "h",main="Instance from Class 4")
# Out:
# Plot with title "Instance from Class 4"

# %%
x_move=as.vector(x_acc[96,])
z_move=as.vector(z_acc[96,])
y_move=as.vector(y_acc[96,])


total <- rbind(x_move,y_move,z_move)
total=t(total)
total=total[-1,]
total=as.data.frame(total)
names(total)=c('x_acc','y_acc','z_acc')

velocity_x=cumsum(total$x_acc)
velocity_y=cumsum(total$y_acc)
velocity_z=cumsum(total$z_acc)
velocity=data.frame(velocity_x,velocity_y,velocity_z)


location_x=cumsum(velocity_x)
location_y=cumsum(velocity_y)
location_z=cumsum(velocity_z)
location=data.frame(location_x,location_y,location_z)



scatterplot3d(location,type = "h",main="Instance from Class 5")
# Out:
# Plot with title "Instance from Class 5"

# %%
x_move=as.vector(x_acc[77,])
z_move=as.vector(z_acc[77,])
y_move=as.vector(y_acc[77,])


total <- rbind(x_move,y_move,z_move)
total=t(total)
total=total[-1,]
total=as.data.frame(total)
names(total)=c('x_acc','y_acc','z_acc')

velocity_x=cumsum(total$x_acc)
velocity_y=cumsum(total$y_acc)
velocity_z=cumsum(total$z_acc)
velocity=data.frame(velocity_x,velocity_y,velocity_z)


location_x=cumsum(velocity_x)
location_y=cumsum(velocity_y)
location_z=cumsum(velocity_z)
location=data.frame(location_x,location_y,location_z)



scatterplot3d(location,type = "h",main="Instance from Class 1")
# Out:
# Plot with title "Instance from Class 1"

# %%
x_move=as.vector(x_acc[101,])
z_move=as.vector(z_acc[101,])
y_move=as.vector(y_acc[101,])


total <- rbind(x_move,y_move,z_move)
total=t(total)
total=total[-1,]
total=as.data.frame(total)
names(total)=c('x_acc','y_acc','z_acc')

velocity_x=cumsum(total$x_acc)
velocity_y=cumsum(total$y_acc)
velocity_z=cumsum(total$z_acc)
velocity=data.frame(velocity_x,velocity_y,velocity_z)


location_x=cumsum(velocity_x)
location_y=cumsum(velocity_y)
location_z=cumsum(velocity_z)
location=data.frame(location_x,location_y,location_z)



scatterplot3d(location,type = "h",main="Instance from Class 2")
# Out:
# Plot with title "Instance from Class 2"

# %%
x_move=as.vector(x_acc[86,])
z_move=as.vector(z_acc[86,])
y_move=as.vector(y_acc[86,])


total <- rbind(x_move,y_move,z_move)
total=t(total)
total=total[-1,]
total=as.data.frame(total)
names(total)=c('x_acc','y_acc','z_acc')

velocity_x=cumsum(total$x_acc)
velocity_y=cumsum(total$y_acc)
velocity_z=cumsum(total$z_acc)
velocity=data.frame(velocity_x,velocity_y,velocity_z)


location_x=cumsum(velocity_x)
location_y=cumsum(velocity_y)
location_z=cumsum(velocity_z)
location=data.frame(location_x,location_y,location_z)



scatterplot3d(location,type = "h",main="Instance from Class 7")
# Out:
# Plot with title "Instance from Class 7"

# %%
install.packages("repr")

library(data.table)
library(repr)
library(ggplot)
# Out:
# also installing the dependencies 'rlang', 'pillar'
#   There are binary versions available but the source versions are later:
#        binary source needs_compilation
# rlang  0.4.11 0.4.12              TRUE
# pillar  1.6.0  1.6.4             FALSE
#
#   Binaries will be installed
# package 'rlang' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'rlang'"Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problem copying D:\Program Files\anaconda\envs\ie48b\Lib\R\library\00LOCK\rlang\libs\x64\rlang.dll to D:\Program Files\anaconda\envs\ie48b\Lib\R\library\rlang\libs\x64\rlang.dll: Permission denied"Warning message:
# "restored 'rlang'"
# package 'repr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\DELL\AppData\Local\Temp\RtmpYHjAkx\downloaded_packages
# installing the source package 'pillar'
#
# Warning message in install.packages("repr"):
# "installation of package 'pillar' had non-zero exit status"Warning message:
# "package 'repr' was built under R version 3.6.3"
# Error in value[[3L]](cond): Package 'repr' version 0.19.2 cannot be unloaded:
#  Error in unloadNamespace(package) : namespace 'repr' is imported by 'IRkernel', 'IRdisplay' so cannot be unloaded
#
# Traceback:
#
# 1. library(repr)
# 2. tryCatch(unloadNamespace(package), error = function(e) {
#  .     P <- if (!is.null(cc <- conditionCall(e)))
#  .         paste("Error in", deparse(cc)[1L], ": ")
#  .     else "Error : "
#  .     stop(gettextf("Package %s version %s cannot be unloaded:\n %s",
#  .         sQuote(package), oldversion, paste0(P, conditionMessage(e),
#  .             "\n")), domain = NA)
#  . })
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. value[[3L]](cond)
# 6. stop(gettextf("Package %s version %s cannot be unloaded:\n %s",
#  .     sQuote(package), oldversion, paste0(P, conditionMessage(e),
#  .         "\n")), domain = NA)

# %%
# Out:
# function (object, ...)
# UseMethod("update")
# <bytecode: 0x0000000040188918>
# <environment: namespace:stats>

# %%
#setnames(x_acc,'X1','class')


x_acc$class=as.vector(x_acc$class)
x_acc=as.data.table(x_acc)
x_acc=x_acc[order(class)]
x_acc[,class:=as.character(class)]
x_acc[,id:=1:.N]

long_x=melt(x_acc,id.vars=c('id','class'))


long_x[,time:=as.numeric(gsub("\\D", "", variable))-1]

long_x=long_x[,list(id,class,time,value)]
long_x=long_x[order(id,time)]

ggplot(long_x, aes(time,value)) + geom_line(aes(color=as.character(id)),) +
  facet_wrap(~class)


selected_series=1
segment_length=5


long_x=long_x[order(id,time)]

data_ts=long_x[id==selected_series]$value
paa_rep=repr_paa(data_ts, segment_length, meanC)
plot(paa_rep,type='l')
paa_rep


dummy_time=c(1:(length(paa_rep)-1))*segment_length 
dummy_time=c(dummy_time,nrow(data_plot))   



data_plot=long_x[id==selected_series]




dt_paa=data.table(time=dummy_time,paa_rep=paa_rep)
head(dt_paa)

data_plot=merge(data_plot,dt_paa,by='time',all.x=T)
data_plot[,paa_rep:=nafill(paa_rep,'nocb')] 



data_plot=melt(data_plot,id.vars='time',
               measure.vars=c('value','paa_rep'))

ggplot(data_plot,aes(x=time,y=value,color=variable))+
  geom_line()

data_plot=merge(data_plot,long_x[id==selected_series,list(time,obs=value)],by='time')

head(data_plot)

data_plot[,list(sse=sum((value-obs)^2)),list(variable)]
# Out:
# Error in ggplot(long_x, aes(time, value)): "ggplot" fonksiyonu bulunamadı
# Traceback:

# %%
selected_dt=long_x[id==selected_series]

tree_fit=rpart(value~time,selected_dt,control=rpart.control(maxdepth=1))

fancyRpartPlot(tree_fit)

selected_dt[,tree_rep:=predict(tree_fit,selected_dt)]

data_plot=melt(selected_dt,id.vars='time',measure.vars=c('value','tree_rep'))

ggplot(data_plot,aes(x=time,y=value,color=variable))+
  geom_line()
